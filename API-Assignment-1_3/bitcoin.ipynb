# %%
import sys
import json
import requests

# %% [markdown]
# ##View the Bitcoin Price Index (BPI) in real-time.

# %%
response = requests.get("https://api.coindesk.com/v1/bpi/currentprice.json")

# %%
json.loads(response.text)
# Out:
# {'time': {'updated': 'Mar 9, 2024 09:51:59 UTC',
#   'updatedISO': '2024-03-09T09:51:59+00:00',
#   'updateduk': 'Mar 9, 2024 at 09:51 GMT'},
#  'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org',
#  'chartName': 'Bitcoin',
#  'bpi': {'USD': {'code': 'USD',
#    'symbol': '&#36;',
#    'rate': '68,378.822',
#    'description': 'United States Dollar',
#    'rate_float': 68378.8223},
#   'GBP': {'code': 'GBP',
#    'symbol': '&pound;',
#    'rate': '53,179.988',
#    'description': 'British Pound Sterling',
#    'rate_float': 53179.988},
#   'EUR': {'code': 'EUR',
#    'symbol': '&euro;',
#    'rate': '62,483.474',
#    'description': 'Euro',
#    'rate_float': 62483.4738}}}
