# %%
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb+srv://mori_momtaz:admin1234@cluster1.rmndo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1")

mydb = myclient["Move"]

# %%
mycol = mydb["cast"]

# %%
mylist = [
  { "name": "Tokyo", "gender": "Female", "boyfriend": "Rio" },
  { "name": "The Professor", "Role": "Manager" },
  { "name": "Nairobi" },
  { "name": "Rio", "gender": "Male" },
]

x = mycol.insert_many(mylist)

# %%
result = mycol.find({
    "$expr": {"$lt": [{"$strLenCP": "$name"}, 5]}
})

for name in result:
    print(name)
# Out:
# {'_id': ObjectId('67023448f14d797fde3ea600'), 'name': 'Rio', 'gender': 'Male'}
# {'_id': ObjectId('67023d12745282f7ce7d3bf7'), 'name': 'Rio', 'gender': 'Male'}
